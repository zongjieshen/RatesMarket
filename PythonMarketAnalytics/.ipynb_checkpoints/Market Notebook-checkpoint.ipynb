# %%
import Market as mkt
import pandas as pd
from datetime import datetime, timedelta
valueDate = datetime(2021, 12, 31)

baseMarket = mkt.MarketFactory.Create('baseMarket',valueDate)
baseMarket.GetItems()
baseMarket.YcShock('AUDSwap3m','pillar',0.0001)
# Out:
# AUDBasis6m3m6M 2022-07-04 00:00:00 has another pillar having the same maturity
# AUDBILL6M 2022-07-04 00:00:00 has another pillar having the same maturity
# AUDBasis3m1m6M 2022-07-04 00:00:00 has another pillar having the same maturity
# AUDBILL6M 2022-07-04 00:00:00 has another pillar having the same maturity
# AUDSwap build status is True
# JPYOIS build status is True
# AUCPI build status is True
# AUDSwap3m build status is True
# AUDSwap1m build status is True
# GBPOIS build status is True
# AUDSwap6m build status is True
# AUDBondGov build status is True
# AUD.Bond.Gov.BEI build status is True

# %%
import dateutil.relativedelta 
baseMarket.GetItems()
date_list = [valueDate + dateutil.relativedelta.relativedelta(months=3) for x in range(100)] 
baseMarket.GetMarketItem('AUD.Bond.Gov.BEI').view()
# Out:
# AUD.Bond.Gov.BEI
# 1985-03-31 37.9000000000
# 1985-06-30 38.8000000000
# 1985-09-30 39.7000000000
# 1985-12-31 40.5000000000
# 1986-03-31 41.4000000000
# 1986-06-30 42.1000000000
# 1986-09-30 43.2000000000
# 1986-12-31 44.4000000000
# 1987-03-31 45.3000000000
# 1987-06-30 46.0000000000
# 1987-09-30 46.8000000000
# 1987-12-31 47.6000000000
# 1988-03-31 48.4000000000
# 1988-06-30 49.3000000000
# 1988-09-30 50.2000000000
# 1988-12-31 51.2000000000
# 1989-03-31 51.7000000000
# 1989-06-30 53.0000000000
# 1989-09-30 54.2000000000
# 1989-12-31 55.2000000000
# 1990-03-31 56.2000000000
# 1990-06-30 57.1000000000
# 1990-09-30 57.5000000000
# 1990-12-31 59.0000000000
# 1991-03-31 58.9000000000
# 1991-06-30 59.0000000000
# 1991-09-30 59.3000000000
# 1991-12-31 59.9000000000
# 1992-03-31 59.9000000000
# 1992-06-30 59.7000000000
# 1992-09-30 59.8000000000
# 1992-12-31 60.1000000000
# 1993-03-31 60.6000000000
# 1993-06-30 60.8000000000
# 1993-09-30 61.1000000000
# 1993-12-31 61.2000000000
# ...

# %%
import dateutil.relativedelta 
#curve = baseMarket.marketItems['AUDSwap'] 
#dv01 = curve.Dv01AtEachPillar('pillar',0.0001) 
date_list = [valueDate + dateutil.relativedelta.relativedelta(months=3*x) for x in range(100)] 
curves = list(baseMarket.Get)
df = mkt.Curve.Charts(list(baseMarket.marketItems.values()), 'zero', date_list,'3m')

df.plot(figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Dates'>

# %%
filepath = r'C:\Users\Zongjie\source\repos\zongjieshen\PythonMarketAnalytics\PythonMarketAnalytics\Market\BondYield.xlsx'

df = pd.read_excel(filepath,sheet_name='InflationCurve').iloc[1]
'test' in df
# Out:
# False
